# %% [markdown]
# **Download Stuff**

# %%
# !apt install tesseract-ocr
# !pip install pytesseract
# !pip install pillow==7.0.0
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# 0 upgraded, 0 newly installed, 0 to remove and 39 not upgraded.
# ...
#   Using cached Pillow-9.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
# ...
#   Attempting uninstall: Pillow
#     Found existing installation: Pillow 7.0.0
#     Uninstalling Pillow-7.0.0:
#       Successfully uninstalled Pillow-7.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# ...
#   Using cached Pillow-7.0.0-cp37-cp37m-manylinux1_x86_64.whl (2.1 MB)
# ...
#   Attempting uninstall: pillow
#     Found existing installation: Pillow 9.1.0
#     Uninstalling Pillow-9.1.0:
# ...

# %%
# !mkdir finalized
# !mkdir states
# !wget -O states/California.jpg https://gisgeography.com/wp-content/uploads/2020/02/California-County-Map-2048x1967.jpg states
# !wget -O states/Alabama.jpg https://gisgeography.com/wp-content/uploads/2013/02/Alabama-County-Map.jpg states
# !wget -O states/Arizona.png https://gisgeography.com/wp-content/uploads/2020/02/Arizona-County-Map.png states
# !wget -O states/Arkansas.jpg https://gisgeography.com/wp-content/uploads/2020/02/Arkansas-County-Map.jpg states
# !wget -O states/Colorado.png https://gisgeography.com/wp-content/uploads/2013/02/Colorado-County-Map.png states
# !wget -O states/Connecticut.png https://gisgeography.com/wp-content/uploads/2013/02/Connecticut-County-Map.png states
# !wget -O states/Delaware.png https://gisgeography.com/wp-content/uploads/2013/02/Delaware-County-Map.png states
# !wget -O states/Florida.jpg https://gisgeography.com/wp-content/uploads/2020/02/Florida-County-Map.jpg states
# !wget -O states/Georgia.jpg https://gisgeography.com/wp-content/uploads/2020/02/Georgia-County-Map.jpg states
# !wget -O states/Idaho.png https://gisgeography.com/wp-content/uploads/2020/02/Idaho-County-Map.png states
# !wget -O states/Illinois.jpg https://gisgeography.com/wp-content/uploads/2020/02/Illinois-County-Map.jpg states
# !wget -O states/Indiana.jpg https://gisgeography.com/wp-content/uploads/2020/02/Indiana-County-Map.jpg states
# !wget -O states/Iowa.png https://gisgeography.com/wp-content/uploads/2020/02/Iowa-County-Map.png states
# !wget -O states/Kansas.png https://gisgeography.com/wp-content/uploads/2020/02/Kansas-County-Map.png states
# !wget -O states/Kentucky.jpg https://gisgeography.com/wp-content/uploads/2020/02/Kentucky-County-Map.jpg states
# !wget -O states/Louisiana.jpg https://gisgeography.com/wp-content/uploads/2013/01/Louisiana-County-Map-0.jpg states
# !wget -O states/Maine.jpg https://gisgeography.com/wp-content/uploads/2013/02/Maine-County-Map.jpg states
# !wget -O states/Maryland.jpg https://gisgeography.com/wp-content/uploads/2020/02/Maryland-County-Map.jpg states
# !wget -O states/Massachusetts.png https://gisgeography.com/wp-content/uploads/2020/02/Massachusetts-County-Map-1265x805.png states
# !wget -O states/Michigan.jpg https://gisgeography.com/wp-content/uploads/2020/02/Michigan-County-Map.jpg states
# !wget -O states/Minnesota.jpg https://gisgeography.com/wp-content/uploads/2020/02/Minnesota-County-Map.jpg states
# !wget -O states/Mississippi.png https://gisgeography.com/wp-content/uploads/2020/02/Mississippi-County-Map.png states
# !wget -O states/Missouri.jpg https://gisgeography.com/wp-content/uploads/2020/02/Missouri-County-Map.jpg states
# !wget -O states/Montana.png https://gisgeography.com/wp-content/uploads/2020/02/Montana-County-Map.png states
# !wget -O states/Nebraska.png https://gisgeography.com/wp-content/uploads/2020/02/Nebraska-County-Map.png states
# !wget -O states/Nevada.png https://gisgeography.com/wp-content/uploads/2020/02/Nevada-County-Map.png states
# !wget -O states/New_Hampshire.png https://gisgeography.com/wp-content/uploads/2020/02/New-Hampshire-County-Map.png states
# !wget -O states/New_Jersey.jpg https://gisgeography.com/wp-content/uploads/2020/02/New-Jersey-County-Map.jpg states
# !wget -O states/New_Mexico.png https://gisgeography.com/wp-content/uploads/2020/02/New-Mexico-County-Map.png states
# !wget -O states/New_York.jpg https://gisgeography.com/wp-content/uploads/2020/02/New-York-County-Map.jpg states
# !wget -O states/North_Carolina.jpg https://gisgeography.com/wp-content/uploads/2020/02/North-Carolina-County-Map.jpg states
# !wget -O states/Ohio.jpg https://gisgeography.com/wp-content/uploads/2020/02/Ohio-County-Map.jpg states
# !wget -O states/Oklahoma.png https://gisgeography.com/wp-content/uploads/2020/02/Oklahoma-County-Map.png states
# !wget -O states/Oregon.png https://gisgeography.com/wp-content/uploads/2020/02/Oregon-County-Map.png states
# !wget -O states/Pennsylvania.jpg https://gisgeography.com/wp-content/uploads/2020/02/Pennsylvania-County-Map.jpg states
# !wget -O states/South_Carolina.jpg https://gisgeography.com/wp-content/uploads/2020/02/South-Carolina-County-Map.jpg states
# !wget -O states/Tennessee.jpg https://gisgeography.com/wp-content/uploads/2020/02/Tennessee-County-Map.jpg states
# !wget -O states/Texas.jpg https://gisgeography.com/wp-content/uploads/2020/02/Texas-County-Map.jpg states
# !wget -O states/Utah.png https://gisgeography.com/wp-content/uploads/2020/02/Utah-County-Map.png states
# !wget -O states/Vermont.png https://gisgeography.com/wp-content/uploads/2020/02/Vermont-County-Map.png states
# !wget -O states/Virginia.jpg https://gisgeography.com/wp-content/uploads/2020/02/Virginia-County-Map.jpg states
# !wget -O states/Washington.jpg https://gisgeography.com/wp-content/uploads/2020/02/Washington-County-Map.jpg states
# !wget -O states/West_Virginia.jpg https://gisgeography.com/wp-content/uploads/2020/02/West-Virginia-County-Map.jpg states
# !wget -O states/Wisconsin.jpg https://gisgeography.com/wp-content/uploads/2020/02/Wisconsin-County-Map.jpg states
# !wget -O states/North_Dakota.jpg https://gisgeography.com/wp-content/uploads/2020/02/North-Dakota-County-Map.png states
# !wget -O states/South_Dakota.jpg https://gisgeography.com/wp-content/uploads/2020/02/South-Dakota-County-Map.png states
# !wget -O states/Wyoming.jpg https://gisgeography.com/wp-content/uploads/2020/03/Wyoming-County-Map.png states

# %% [markdown]
# ## Code

# %%
# Import libraries
import sys
import matplotlib.pyplot as plt
import numpy as np
import cv2
import re

# cv2.imshow() is broken for colab, can use this patched function instead
from google.colab.patches import cv2_imshow

# %%
def show_image(img, scale=1.0, download=False, path=""):
    width = int(img.shape[1] * scale)
    height = int(img.shape[0] * scale)
    dim = (width, height)
    resized = cv2.resize(img, dim, interpolation=cv2.INTER_AREA)
    if download:
      cv2.imwrite(path, resized)
    cv2_imshow(resized)

# %%
# Load image into numpy array
img_path = "/content/states/Wyoming.jpg"
img_path = img_path.replace("/content/","")
img = cv2.imread(img_path)
show_image(img, 0.3)
# Out:
# <PIL.Image.Image image mode=RGB size=600x492 at 0x7F1D3385EC50>

# %% [markdown]
# ### Detect possible text regions

# %%
# rough cleanup - removing lines
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
blur = cv2.blur(gray,(3,3))
ret,thresh = cv2.threshold(blur, 130, 255, cv2.THRESH_BINARY_INV)
show_image(thresh, 0.33)
# Out:
# <PIL.Image.Image image mode=L size=660x541 at 0x7F1D33826150>

# %%
# Get rough estimate of text regions
kernel = np.ones((3,3),np.uint8)
dilation = cv2.dilate(thresh, kernel, iterations = 3)
show_image(dilation, 0.33)
# Out:
# <PIL.Image.Image image mode=L size=660x541 at 0x7F1D3375DCD0>

# %%
def get_contour_extreme_points(c):
    # determine the most extreme points along the contour
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    # print(extLeft, extRight, extTop, extBot)
    return (extLeft[0], extTop[1]), (extRight[0], extBot[1])
    

def get_text_bounding_boxes(src_img):
    contours, hierarchy = cv2.findContours(src_img, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    bounds = []
    min_area = 10
    
    right_left_gap = 10
    for contour in contours:
        area = cv2.contourArea(contour)
        if area > min_area:
            cur_point = get_contour_extreme_points(contour)
            if len(bounds) != 0:
              last = bounds[-1]
              left_right_diff = abs(last[0][0] - cur_point[1][0])
              right_left_diff = abs(last[0][0] - cur_point[0][0])
              if left_right_diff <= right_left_gap or right_left_diff <= right_left_gap:
                new_point_left = min(last[0][0], cur_point[0][0])
                new_point_top = min(last[0][1], cur_point[0][1])
                new_point_right = max(last[1][0], cur_point[1][0])
                new_point_bot = max(last[1][1], cur_point[1][1])
                new_point = (new_point_left, new_point_top), (new_point_right, new_point_bot)
                del bounds[-1]
                bounds.append(new_point)
                continue
            bounds.append(cur_point)
    return bounds
def optimize(bounds):
  n = len(bounds)
  top_bot_gap = 15
  right_left_gap = 10
  bounds = sorted(bounds, key = lambda x: x[0][0])
  for i in range(0, n):
    cur_i = bounds[i]
    if cur_i is None:
      continue
    for j in range(i+1, n):
      cur_j = bounds[j]
      if cur_j is None:
        continue;
      right_left_diff = abs(cur_i[1][0] - cur_j[0][0])
      top_bot_diff = abs(cur_i[1][1] - cur_j[0][1])
      bot_bot_diff = abs(cur_i[1][1] - cur_j[1][1])
      
      if right_left_diff <= right_left_gap and bot_bot_diff <= top_bot_gap:
        new_point_left = min(cur_i[0][0], cur_j[0][0])
        new_point_top = min(cur_i[0][1], cur_j[0][1])
        new_point_right = max(cur_i[1][0], cur_j[1][0])
        new_point_bot = max(cur_i[1][1], cur_j[1][1])
        new_point = (new_point_left, new_point_top), (new_point_right, new_point_bot)
        bounds[i] = new_point
        cur_i = bounds[i]
        bounds[j] = None
  new_list = []
  for val in bounds:
    if val is not None:
      new_list.append(val)
  return new_list

def draw_bounds(src_img, bounds, buffer=0):
    img_copy = np.copy(src_img)
    color = (255,0,255)
    thickness = 1

    for start_point, end_point in bounds:
        img_copy = cv2.rectangle(img_copy, 
                                 (start_point[0]-buffer, start_point[1]-buffer), 
                                 (end_point[0]+buffer, end_point[1]+buffer), 
                                 color, thickness)
    
    return img_copy

# manually find text regions(text detection)
bounds = get_text_bounding_boxes(dilation)
bounds = optimize(bounds)
# draw rectangles around text
img_bounds = draw_bounds(img, bounds)
show_image(img_bounds, .5)
# Out:
# <PIL.Image.Image image mode=RGB size=1000x821 at 0x7F1D33759E10>

# %% [markdown]
# ### OCR

# %%
population_dict = dict()
with open('sample_data/population.txt') as f:
    for line in f:
        line = line.strip()
        line = line.replace("\n", "")
        line = re.split(r'\t+', line)
        state = line[0]
        county = line[1]
        county = county.replace("County","").strip()
        county = county.replace(" ","")
        county = county.lower()
        population = line[2]
        if state not in population_dict: 
            population_dict[state] = {}
        population_dict[state][county] = population

# %%
states_dict = dict()
with open('sample_data/states.txt') as f:
    for line in f:
        line = line.strip()
        line = line.replace("\n", "")
        line = re.split('\s+', line)
        state = line[0]
        state = state.lower()
        abbreviation = line[1]
        states_dict[state] = abbreviation

# %%
img_path_temp = img_path.replace(".jpg", "")
img_path_temp = img_path_temp.replace(".png", "")
img_path_temp = img_path_temp.replace("states/", "")
img_path_temp = img_path_temp.lower()

# %%
import pytesseract
from PIL import Image
import re
state_name = ""
for state in states_dict:
  state = state.lower()
  if state == img_path_temp:
    state_name = state
    break   

def do_ocr(src_img, bounds, buffer=5):
    texts = []
    for start_point, end_point in bounds:
        # crop each text region into a seperate image before passing it to tesseract
        crop = img_rgb[start_point[1]-buffer:end_point[1]+buffer,
                       start_point[0]-buffer:end_point[0]+buffer,
                       :]

        # convert cropped image region from numpy(opencv) to pillow format
        im_pil = Image.fromarray(crop)

        # do ocr
        text = pytesseract.image_to_string(im_pil)
        text = re.sub(r'[^a-zA-Z]', '', text)
        text = text.lower()
        
        if text in population_dict[states_dict[state_name]]:
          texts.append(population_dict[states_dict[state_name]][text])
        else:
          texts.append("")

    return texts
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
texts = do_ocr(img_rgb, bounds)

# %%
print(state_name)
# Out:
# wyoming

# %% [markdown]
# ### Show Results

# %%
start = img_path.rindex('/')
img_path = "finalized/"+img_path[start+1:]

# %%
def draw_texts(src_img, texts, bounds, offset):
    img_copy = np.copy(src_img)
    color = (255,0,255)
    thickness = 1
    font = cv2.FONT_HERSHEY_COMPLEX
    fontScale = 0.5
    thickness = 1

    for i, text in enumerate(texts):
        if len(text) > 0:
            start_point, end_point = bounds[i]
            position = (start_point[0], end_point[1]+offset)
            image = cv2.putText(img_copy, text, position, font, 
                            fontScale, color, thickness, cv2.LINE_AA)
    return img_copy
text_image = draw_texts(img, texts, bounds, 15)
img = show_image(text_image, download=True, path=img_path)
# Out:
# <PIL.Image.Image image mode=RGB size=2000x1642 at 0x7F1D33826210>

# %%
#!zip -r /content/file.zip /content/finalized
